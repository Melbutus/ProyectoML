# %%
import pandas as pd
import numpy as np   
import seaborn as sns
from autoviz.AutoViz_Class import AutoViz_Class
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt 
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import warnings
warnings.filterwarnings("ignore")
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
# Cargar los archivos Parquet
df_completo = pd.read_parquet(r'dataset_completo.parquet')
df_completo.head()
# Out:
#    movie_id      actor_name     director_name   director_movie_id  budget  \
# 0    16420   laurence fishburne  oliver parker       56710.0          0
# 1    16420          irène jacob  oliver parker       56710.0          0
# 2    16420      kenneth branagh  oliver parker       56710.0          0
# 3    16420     nathaniel parker  oliver parker       56710.0          0
# 4    16420            indra ové  oliver parker       56710.0          0
#
#   original_language  \
# 0         en
# 1         en
# 2         en
# 3         en
# 4         en
#
#                                                                       overview                                                                      \
# 0  The evil Iago pretends to be friend of Othello in order to manipulate him to serve his own end in the film version of this Shakespeare classic.
# ...

# %%
'''print(df_credits.columns)
print(df_movies.columns)

# Renombrar la columna 'id' en df_movies a 'movie_id' para luego poder unir las dos a un dataset común mediante este campo
df_movies = df_movies.rename(columns={'id': 'movie_id'})'''
# Out:
# Index(['movie_id', 'actor_name', 'director_name', 'director_movie_id'], dtype='object')
# Index(['budget', 'id', 'original_language', 'overview', 'popularity',
#        'release_date', 'revenue', 'runtime', 'title', 'vote_average',
#        'vote_count', 'generos', 'production_countries_clean',
#        'production_companies_clean', 'spoken_languages_clean', 'release_year'],
#       dtype='object')

# %%
import matplotlib
from autoviz.AutoViz_Class import AutoViz_Class

# Cambiar el backend de matplotlib a 'Agg' para evitar la visualización de gráficos
matplotlib.use('Agg')

AV = AutoViz_Class()
df = AV.AutoViz(filename="", dfte=df_completo)

# Volver a activar el backend estándar si se necesita más adelante en el código
matplotlib.use('TkAgg')  # Si usas Jupyter, podrías querer 'inline' en su lugar

# Imprimir el dataframe generado por AutoViz
print(df)
# Out:
# Shape of your Data Set loaded: (35377, 19)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# movie_id of type=Int64 is not classified
#     Number of Numeric Columns =  5
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  3
#     Number of NLP String Columns =  5
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
# No of columns classified 18 does not match 19 total cols. Continuing...
#  Missing columns = ['movie_id']
# ...

# %%
'''# Revisión de valores nulos
print(df_credits.isnull().sum())
print(df_movies.isnull().sum())'''
# Out:
# movie_id             0
# actor_name           0
# director_name        0
# director_movie_id    0
# dtype: int64
# budget                        0
# movie_id                      0
# original_language             0
# overview                      0
# popularity                    0
# release_date                  0
# revenue                       0
# runtime                       0
# title                         0
# vote_average                  0
# vote_count                    0
# generos                       0
# production_countries_clean    0
# production_companies_clean    0
# spoken_languages_clean        0
# release_year                  0
# dtype: int64

# %%
'''# Eliminar duplicados exactos
df_credits = df_credits.drop_duplicates()
df_movies = df_movies.drop_duplicates()

# Revisión de duplicados
print(f"Duplicados en dfcredits_reducido: {df_credits.duplicated().sum()}")
print(f"Duplicados en dfmovies_reducido: {df_movies.duplicated().sum()}")
'''
# Out:
# Duplicados en dfcredits_reducido: 0
# Duplicados en dfmovies_reducido: 0

# %%
# Calcular el porcentaje de 0s en cada columna relevante, teniendo en cuenta que los pusimos anteriormente para rellenar nulos, dada la salida 'budget' y 'revenue' nos indica que no disponemos de datos basicamente.
for col in ['budget', 'revenue', 'popularity', 'runtime', 'vote_average', 'vote_count']:
    porcentaje_cero = (df_completo[col] == 0).mean() * 100
    print(f"El porcentaje de 0s en la columna '{col}' es: {porcentaje_cero:.2f}%")
# Out:
# El porcentaje de 0s en la columna 'budget' es: 86.28%
# El porcentaje de 0s en la columna 'revenue' es: 88.99%
# El porcentaje de 0s en la columna 'popularity' es: 0.03%
# El porcentaje de 0s en la columna 'runtime' es: 5.45%
# El porcentaje de 0s en la columna 'vote_average' es: 4.33%
# El porcentaje de 0s en la columna 'vote_count' es: 4.21%

# %%
# Cambiar el backend de matplotlib a inline para Jupyter Notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
# Distribución del presupuesto
plt.figure(figsize=(10, 6))
sns.histplot(df_completo['budget'], bins=50, kde=True)
plt.title('Distribución del Presupuesto')
plt.xlabel('Presupuesto')
plt.ylabel('Frecuencia')
plt.show()

# %%
wordcloud = WordCloud(width=800, height=400).generate(" ".join(df_completo['title'].dropna()))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras de Títulos')
plt.show()

# %%
# Combina todos los textos del campo 'overview' en una sola cadena
text_overview = " ".join(df_completo['overview'].dropna())

# Genera la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_overview)

# Muestra la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras de Overview')
plt.show()

# %%
# Combina todos los nombres de actores en una sola cadena
text_actors = " ".join(df_completo['actor_name'].dropna())

# Genera la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_actors)

# Muestra la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras de Actores')
plt.show()

# %%
# Combina todos los nombres de directores en una sola cadena
text_directors = " ".join(df_completo['director_name'].dropna())

# Genera la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_directors)

# Muestra la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras de Directores')
plt.show()

# %%
# Combina todos los idiomas en una sola cadena
text_languages = " ".join(df_completo['original_language'].dropna())

# Genera la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_languages)

# Muestra la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras de Idiomas Hablados')
plt.show()

# %%
'''# Convertir 'movie_id' en ambos DataFrames a int64 porque si estan en diferente formato no puedo unir
df_credits['movie_id'] = pd.to_numeric(df_credits['movie_id'], errors='coerce').astype('Int64')
df_movies['movie_id'] = pd.to_numeric(df_movies['movie_id'], errors='coerce').astype('Int64')

# Unir los datasets utilizando 'movie_id' como clave
df_unido = pd.merge(df_credits, df_movies, on='movie_id', how='inner')
'''

# %%
# Seleccionar las columnas que deseas mantener para el pre procesamiento de datos
#df_preprocesado = df_unido[['title', 'movie_id', 'release_date', 'vote_count', 'vote_average', 'actor_name', 'director_name', 'revenue', 'budget']]

# %%
'''# Eliminar espacios en blanco al inicio y final de las cadenas
df_preprocesado['title'] = df_preprocesado['title'].str.strip()
df_preprocesado['actor_name'] = df_preprocesado['actor_name'].str.strip()
df_preprocesado['director_name'] = df_preprocesado['director_name'].str.strip()

# Reemplazar dobles espacios o caracteres especiales, si los hay
df_preprocesado['title'] = df_preprocesado['title'].str.replace('\s+', ' ', regex=True)
df_preprocesado['actor_name'] = df_preprocesado['actor_name'].str.replace('\s+', ' ', regex=True)
df_preprocesado['director_name'] = df_preprocesado['director_name'].str.replace('\s+', ' ', regex=True)

df_preprocesado.drop_duplicates(subset=['title', 'actor_name', 'director_name'], keep='first', inplace=True)'''

# %%
# Verificar que todas las cadenas estén correctamente formateadas
df_completo.info()
df_completo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35377 entries, 0 to 35392
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   movie_id                    35377 non-null  Int64
#  1   actor_name                  35377 non-null  object
#  2   director_name               35377 non-null  object
#  3   director_movie_id           35377 non-null  float64
#  4   budget                      35377 non-null  int32
#  5   original_language           35377 non-null  object
#  6   overview                    35377 non-null  object
#  7   popularity                  35377 non-null  float64
#  8   release_date                35377 non-null  datetime64[ns]
#  9   revenue                     35377 non-null  int32
#  10  runtime                     35377 non-null  float64
#  11  title                       35377 non-null  object
#  12  vote_average                35377 non-null  float64
# ...

# %%
# Guardar el dataset en formato Parquet
'''df_preprocesado.to_parquet('dataset_preprocesado.parquet')'''
